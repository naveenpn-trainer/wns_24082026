# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Load 'users_001.csv' into DataFrame

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
display(df)

# %% [markdown]
# # [Transaction 01] - Write DataFrame as Delta
#
# * part-00000-fd7f3814-19ea-4763-9f71-996f599bfd84.c000.snappy.parquet

# %%
df.write.format("DELTA").save(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_delta"
)

# %% [markdown]
# # [Transaction 02] - Overwrite Delta Folder
#
# * part-00000-62c5f446-08ca-4a75-a0b0-a37f29ade2b1.c000.snappy.parquet

# %%
from pyspark.sql.functions import col

df.filter(col("country") == "India").write.save(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_delta", mode="OVERWRITE"
)

# %% [markdown]
# # Read Delta

# %%
spark.read.load(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_delta"
).show()

# %% [markdown]
# # [Advantage] - Maintains Versions

# %%
spark.read.option("versionAsOf", 0).load(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_delta"
).count()

# %% [markdown]
# # Read Transaction Log

# %% [markdown]
# ## Approach 01

# %%
spark.read.load(
    format="text",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_delta/_delta_log/00000000000000000001.json",
).show(truncate=False)

# %% [markdown]
# ## Approach 02

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(
    spark, "/Volumes/wns24082026/quickstart_schema/sandbox/output_delta/"
)
delta_table.history().display()

# %% [markdown]
# 1. Read Delta as DF
# 2. Create a view on DF
# 3. Updates are allowed

# %%
2
