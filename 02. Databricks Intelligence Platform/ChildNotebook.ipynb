# %%
print("Invoked Child Notebook - I")

# %%
dbutils.widgets.dropdown(
     name="technology",
    defaultValue="2G",
    choices=["2G","3G", "4G", "VOLTE"],
    label="Technology",
)

dbutils.widgets.text(name="customer_name", defaultValue="Select",  label="Customer Name")

# %%
print(dbutils.widgets.get("technology"))
print(dbutils.widgets.get("customer_name"))

# %%
print("Invoked Child Notebook - II")
dbutils.notebook.exit("EXECUTED SUCCESSFULLY")

# %%
print("Invoked Child Notebook - III")
